# %% [markdown]
# # TFM - PLN asociado a la interpretación del contrato de seguros

# %% [markdown]
# ## Autor: Jose Abal Caamaño

# %% [markdown]
# En este cuaderno de Jupyter Notebook, se encuentra el desarrollo de código que he realizado para el trabajo de fin de máster en ciencia de datos. Es un chatbot realizado en Python con la biblioteca NLTK, para evitar posibles errores y tener siempre respuestas normalizadas, he utilizado la biblioteca Unidecode.

# %% [markdown]
# ## Index:
# ## 1. Libraries
# ## 2. Chatbot

# %% [markdown]
# # 1. Libraries

# %%
import pandas as pd
import nltk
import unidecode

# %% [markdown]
# # 2. Chatbot

# %%
#Mensaje de bienvenida del chatbot
print("Hola, soy un chat de ayuda y mi nombre es J. ¿En qué puedo ayudarle?")

#Bucle principal del chatbot
continuar = True
while continuar:
    #Preguntar al usuario si es cliente o si necesita información para serlo
    respuesta = input("¿Es usted cliente? (si/no) ")
    
    #Normalizar la respuesta para eliminar los acentos y que no haya errores de escritura
    respuesta_normalizada = unidecode.unidecode(respuesta.lower())

    #Comprobar la respuesta del usuario y responder en consecuencia
    if respuesta_normalizada == "si":
        #Preguntar si el problema es con el seguro o si necesita información detallada
        respuesta = input("¿Tiene algún problema con su seguro? (si/no) ")
        if respuesta_normalizada == "si":
            print("Entiendo. ¿Podría darme más detalles sobre el problema que está teniendo?")
            # Bucle para preguntas específicas para clientes con problemas
            preguntas_cliente = True
            while preguntas_cliente:
                respuesta = input("¿Qué tipo de problema tiene con su seguro? (Gestión de pólizas, Renovación, Siniestro, Otro) ")
                # Normalizar la respuesta para eliminar los acentos
                respuesta_normalizada = unidecode.unidecode(respuesta.lower())
                if respuesta_normalizada == "gestion de polizas":
            
                    sub_respuesta = input("Ahora puede solicitar la siguiente información:\n"
                                          "1. Información general de la póliza\n"
                                          "2. Estado de los pagos\n"
                                          "3. Ampliaciones de coberturas\n"
                                          "4. Dar de baja la póliza\n"
                                          "Elija una opción: ")
                
                    if sub_respuesta == "1":
                        numero_poliza = input("Por favor, proporcione el número de póliza para obtener la información general del seguro: ")
                        print("Estos son los datos generales de su póliza " + numero_poliza + ":")
                        print("- Tomador:\n"
                              "- Asegurado:\n"
                              "- Tipo de póliza:\n"
                              "- Número de póliza:\n"
                              "- Fecha de efecto:\n"
                              "- Fecha de vencimiento:\n"
                              "- Coberturas y límites:\n"
                              "- Prima:\n")
                        
                    elif sub_respuesta == "2":
                        numero_poliza = input("Por favor, proporcione el número de póliza: ")
                        print("Aquí tiene los datos del estado de los pagos de la póliza " + numero_poliza + ":")
                        print("--> Número de recibo:\n"
                              "- Fecha de pago:\n"
                              "- Cuantía:\n"
                              "- Método de pago:\n"
                              "- Estado del pago:\n"
                              "- Próximo pago:")
                        
                    elif sub_respuesta == "3":
                        numero_poliza = input("Por favor, proporcione el número de póliza: ")
                        print("Las coberturas que se pueden añadir a la póliza " + numero_poliza + " son las siguientes:")
                        print("- Ya que se trata de una póliza de hogar:\n"
                              "- Cobertura de daños por agua: Cubre los daños causados por fugas de agua o inundaciones\n"
                              "- Cobertura de joyas y objetos de valor: Incrementa el límite de cobertura para joyas, obras de arte y otros objetos valiosos.)\n"
                              "- Cobertura de robo fuera del hogar: Cubre los objetos personales que se encuentren fuera del hogar, como en un viaje\n"
                              "- Coberturas por catastrofes naturales: Protege contra los daños causados por terremotos, tormentas, tornados o tsunamis")
                        
                    elif sub_respuesta == "4":
                        numero_poliza = input("Por favor, proporcione el número de póliza: ")
                        print("Hemos recibido la solicitud de baja de la póliza " + numero_poliza + ". Contactaremos con usted para los trámites de cancelación.")
                        
                    else:
                        print("Opción inválida. Por favor, elija un número del 1 al 4.")
                    
                if respuesta_normalizada == "renovacion":
                    sub_respuesta = input("Ahora puede solicitar los siguientes tipos de seguros:\n"
                                          "1. Seguro de vida\n"
                                          "2. Seguro de autos\n"
                                          "3. Seguro de hogar\n"
                                          "4. Responsabilidad Profesional\n"
                                          "Elija una opción: ")
                    if sub_respuesta == "1":
                        numero_poliza = input("Por favor, proporcione el número de póliza para el seguro de vida: ")
                        print("Para renovar la póliza " + numero_poliza + " del seguro de vida, esta es la información que necesitamos:")
                        print("- Información personal del asegurado, incluyendo edad, sexo y ocupación\n"
                              "- Capitales asegurados\n"
                              "- Información sobre beneficiarios designados\n")
                        
                    elif sub_respuesta == "2":
                        numero_poliza = input("Por favor, proporcione el número de póliza para el seguro de autos: ")
                        print("Para renovar la póliza " + numero_poliza + " del seguro de autos, esta es la información que necesitamos:")
                        print("- Detalles del vehículo, como marca, modelo, año, número de matrícula y número de identificación del vehículo\n"
                              "- Información sobre el uso del vehículo (personal, comercial, etc.)\n"
                              "- Kilometraje estimado anual del vehículo\n"
                              "- Historial de conducción, incluyendo accidentes anteriores, multas de tráfico y cualquier infracción relevante\n"
                              "- Información sobre el garaje o lugar de estacionamiento habitual del vehículo\n")
                        
                    elif sub_respuesta == "3":
                        numero_poliza = input("Por favor, proporcione el número de póliza para el seguro de hogar: ")
                        print("Para renovar la póliza " + numero_poliza + " del seguro de hogar, esta es la información que necesitamos:")
                        print("- Valor estimado de la propiedad y contenido\n"
                              "- Detalles de cualquier mejora o renovación realizada en la propiedad\n"
                              "- Información sobre sistemas de seguridad instalados (por ejemplo, alarmas, cámaras de seguridad, etc.)\n"
                              "- Información sobre mascotas en la propiedad\n")
                        
                    elif sub_respuesta == "4":
                        numero_poliza = input("Por favor, proporcione el número de póliza para el seguro de responsabilidad civil: ")
                        print("Para renovar la póliza " + numero_poliza + " del seguro de responsabilidad civil, esta es la información que necesitamos:")
                        print("- Tipo de responsabilidad civil que estás buscando cubrir (general, profesional, etc.)\n"
                              "- Detalles de tu negocio o actividad profesional\n"
                              "- Información sobre reclamaciones o demandas previas presentadas en tu contra\n"
                              "- Límites de cobertura deseados para la póliza de responsabilidad civil\n")
                        
                    else:
                        print("Opción inválida. Por favor, elija un número del 1 al 4.")

                elif respuesta.lower() == "siniestro":
                    print("Lamentamos profundamente su incidente.")
                    numero_poliza = input("Por favor, proporcione el número de póliza: ")
                    detalle_siniestro = input("Por favor, detalle brevemente el siniestro: ")
                    print("Gracias por la información. Nos pondremos en contacto con usted para ayudarle con su siniestro. ¡Muchas gracias!")

                elif respuesta.lower() == "otro":
                    solicitud = input("Por favor, exponga brevemente su problema: ")
                    print("Trasladaremos su solicitud a nuestro departamento de soluciones y nos pondremos en contacto con usted. ¡Muchas gracias!")

                else:
                    print("Lo siento, no he entendido su respuesta. Por favor, seleccione una de las opciones disponibles.")

                # Preguntar si el usuario tiene más preguntas
                respuesta = input("¿Tiene alguna otra pregunta sobre su seguro? (si/no) ")
                if respuesta.lower() == "no":
                    preguntas_cliente = False
                    # Preguntar si el usuario desea realizar otra consulta
                    respuesta = input("¿Desea realizar otra consulta? (si/no) ")
                    if respuesta.lower() == "no":
                        continuar = False
        elif respuesta_normalizada == "no":
            preguntas_informacion = True
            while preguntas_informacion:
                # Preguntar si necesita más información
                respuesta = input("¿Necesita más información sobre " + respuesta.lower() + "? (si/no) ")
                if respuesta.lower() == "no":
                    preguntas_informacion = False
                    # Preguntar si el usuario desea realizar otra consulta
                    respuesta = input("¿Desea realizar otra consulta? (si/no) ")
                    if respuesta.lower() == "no":
                        continuar = False
        else:
            print("Lo siento, no he entendido su respuesta. Por favor, responda con 'si' o 'no'.")
                
    elif respuesta_normalizada == "no":
        print("Estaré encantado de facilitarle toda la información que necesite.")
        preguntas_informacion = True
        while preguntas_informacion:
            # Preguntar qué tipo de información necesita el usuario
            respuesta = input("¿Qué tipo de información necesita para convertirse en cliente? "
                              "Por favor, elija una opción ingresando el número correspondiente:\n"
                              "1. Pólizas disponibles\n"
                              "2. Documentación necesaria\n"
                              "3. Coberturas y Exclusiones\n"
                              "4. Permanencia, bonificaciones y descuentos\n"
                              "Opción: ")
            if respuesta == "1":
                sub_respuesta = input("Ahora puede solicitar los siguientes tipos de seguros:\n"
                                     "1. Seguro de vida\n"
                                     "2. Seguro de autos\n"
                                     "3. Seguro de hogar\n"
                                     "4. Responsabilidad Civil\n"
                                     "Elija una opción: ")
                if sub_respuesta == "1":
                    print("Aquí está la información sobre el seguro de vida:")
                    print("Nuestro seguro de vida brinda protección financiera a tus seres queridos en caso de fallecimiento. Con primas asequibles, garantizamos que tus beneficiarios recibirán una suma asegurada para cubrir gastos funerarios, deudas pendientes o asegurar su bienestarfuturo. Contrata nuestro seguro de vida y ten la tranquilidad de dejar un legado de seguridad económica para quienes más quieres.")
                elif sub_respuesta == "2":
                    print("Aquí está la información sobre el seguro de autos:")
                    print("Nuestro seguro de autos te brinda protección completa y tranquilidad en la carretera. Con cobertura de responsabilidad civil, colisión e integral, estarás protegido contra daños a tu vehículo y a terceros. Además, ofrecemos asistencia en carretera y beneficios adicionales. Conduce con confianza sabiendo que estamos aquí para cuidarte en cada viaje.")
                elif sub_respuesta == "3":
                    print("Aquí está la información sobre el seguro de hogar:")
                    print("Nuestro seguro de hogar protege tu vivienda y tus bienes ante diversos riesgos. Cubrimos daños estructurales, pérdida de contenido, responsabilidad civil y gastos adicionales de vivienda. Mantén tu hogar seguro y protegido con nuestra amplia cobertura y servicio confiable.")
                elif sub_respuesta == "4":
                    print("Aquí está la información sobre el seguro de responsabilidad civil:")
                    print("Nuestro seguro de responsabilidad civil te brinda tranquilidad ante posibles reclamaciones legales. Cubrimos los costes de indemnización y defensa en caso de daños a terceros o accidentes involuntarios. Protege tus activos y garantiza tu seguridad financiera con nuestra sólida cobertura de responsabilidad civil.")
                else:
                    print("Opción inválida. Por favor, elija un número del 1 al 4.")
            
            elif respuesta == "2":
                print("Esta es la documentación necesaria para formalizar el seguro:\n"
                      "- Póliza: Nosotros les facilitaremos un documento estándar del seguro que desea contratar.\n"
                      "- Boletín de adhesión: Es un formulario que debe ser completado y firmado para formalizar su adhesión al seguro, proporcionando información personal y detalles relevantes.\n"
                      "- Fotocopia DNI\n")

            
            elif respuesta == "3":
                continuar = True
                while continuar:
                    print("Por favor, elija una opción:\n"
                          "1. Seguro de vida\n"
                          "2. Seguro de autos\n"
                          "3. Seguro de hogar\n"
                          "4. Seguro de responsabilidad civil\n"
                          "Elija una opción: ")

                    respuesta = input("Ingrese el número de opción deseada: ")

                    if respuesta == "1":
                        while True:
                            print("Estas son las coberturas y exclusiones generales del seguro de vida:\n"
                                  "--> Coberturas:\n"
                                  "- Cobertura por fallecimiento\n"
                                  "- Cobertura por enfermedad terminal\n"
                                  "- Cobertura por invalidez total y permanente\n"
                                  "--> Exclusiones:\n"
                                  "- Suicidio (exclusión inicial)\n"
                                  "- Actos ilegales\n"
                                  "- Guerra y actos de terrorismo\n"
                                  "- Condiciones preexistentes no divulgadas\n")
                            
                            respuesta = input("¿Desea más detalles sobre coberturas y exclusiones? (si/no) ")
                            if respuesta.lower() == "no":
                                break
                            elif respuesta.lower() == "si":
                                break
                            else:
                                print("Respuesta inválida. Por favor, ingrese 'si' o 'no'.")

                    elif respuesta == "2":
                        while True:
                            print("Estas son las coberturas y exclusiones generales del seguro de autos:\n"
                                  "--> Coberturas:\n"
                                  "- Responsabilidad civil\n"
                                  "- Cobertura de colisión\n"
                                  "- Cobertura integral\n"
                                  "- Cobertura de lesiones personales\n"
                                  "--> Exclusiones:\n"
                                  "- Conducir bajo los efectos del alcohol o las drogas\n"
                                  "- Uso no autorizado\n"
                                  "- Daños intencionales\n"
                                  "- Condiciones preexistentes no divulgadas\n")
                            
                            respuesta = input("¿Desea más detalles sobre coberturas y exclusiones? (si/no) ")
                            if respuesta.lower() == "no":
                                break
                            elif respuesta.lower() == "si":
                                break
                            else:
                                print("Respuesta inválida. Por favor, ingrese 'si' o 'no'.")

                    elif respuesta == "3":
                        while True:
                            print("Estas son las coberturas y exclusiones generales del seguro de hogar:\n"
                                  "--> Coberturas:\n"
                                  "- Cobertura de estructura de la vivienda\n"
                                  "- Cobertura de contenidos personales\n"
                                  "- Cobertura de responsabilidad civil\n"
                                  "- Cobertura de gastos adicionales de vivienda\n"
                                  "--> Exclusiones:\n"
                                  "- Daños preexistentes\n"
                                  "- Desgaste normal y mantenimiento\n"
                                  "- Daños intencionales\n"
                                  "- Daños por inundación o terremoto\n")
                            
                            respuesta = input("¿Desea más detalles sobre coberturas y exclusiones? (si/no) ")
                            if respuesta.lower() == "no":
                                break
                            elif respuesta.lower() == "si":
                                break
                            else:
                                print("Respuesta inválida. Por favor, ingrese 'si' o 'no'.")

                    elif respuesta == "4":
                        while True:
                            print("Estas son las coberturas y exclusiones generales del seguro de responsabilidad civil:\n"
                                  "--> Coberturas:\n"
                                  "- Cobertura de responsabilidad civil general\n"
                                  "- Cobertura de responsabilidad civil profesional\n"
                                  "- Cobertura de responsabilidad civil de productos\n"
                                  "- Cobertura de responsabilidad civil de empleadores\n"
                                  "--> Exclusiones:\n"
                                  "- Daños intencionales\n"
                                  "- Reclamos relacionados con prácticas discriminatorias o acoso sexual\n"
                                  "- Daños a la propiedad del asegurado\n"
                                  "- Reclamos relacionados con incumplimiento de contrato\n")
                            
                            respuesta = input("¿Desea más detalles sobre coberturas y exclusiones? (si/no) ")
                            if respuesta.lower() == "no":
                                break
                            elif respuesta.lower() == "si":
                                break
                            else:
                                print("Respuesta inválida. Por favor, ingrese 'si' o 'no'.")

                    else:
                        print("Opción inválida. Por favor, elija un número del 1 al 4.")
                        
                    respuesta = input("¿Puedo ayudarle en algo más? (si/no) ")
                    if respuesta.lower() == "no":
                         continuar = False

                respuesta = input("¿Desea realizar otra consulta? (si/no) ")
                if respuesta.lower() == "no":
                    continuar = False


            elif respuesta == "4":
                print("--> La permanencia de todos nuestros seguros es de mínimo una anualidad.\n"
                      "--> Las bonificaciones de nuevo cliente son:\n"
                          "- Bonificación por no siniestralidad\n"
                          "- Bonificación por antigüedad\n"
                          "- Bonificación por pólizas múltiples\n"
                          "- Bonificación por renovación anticipada\n"
                          "- Bonificación por mejoras en la seguridad\n"
                      "--> Estos son los descuentos a los que podría optar:\n"
                          "- Descuento por sistema de seguridad\n"
                          "- Descuento por conducción segura\n"
                          "- Descuento por pago anual\n"
                          "- Descuento por pólizas múltiples\n"
                          "- Descuento por edad")

            else:
                print("Lo siento, la opción ingresada no es válida. Por favor, elija un número del 1 al 4.")
            
            # Preguntar si necesita más información
            respuesta = input("¿Necesita más información? (si/no) ")
            if respuesta.lower() == "no":
                preguntas_informacion = False
                # Preguntar si el usuario desea realizar otra consulta
                respuesta = input("¿Desea realizar otra consulta? (si/no) ")
                if respuesta.lower() == "no":
                    continuar = False

    else:
        print("Lo siento, no he entendido su respuesta. Por favor, responda con 'si' o 'no'.")

print("¡Gracias por utilizar nuestro servicio! Que tenga un buen día.")
print("J")
# Out:
# Hola, soy un chat de ayuda y mi nombre es J. ¿En qué puedo ayudarle?
